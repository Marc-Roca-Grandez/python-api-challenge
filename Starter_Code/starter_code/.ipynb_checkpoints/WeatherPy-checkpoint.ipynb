# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 620

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + f"appid={weather_api_key}&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
    #     print(city_weather)
        city_lat = (city_weather['coord']['lat'])
        city_lng = (city_weather['coord']['lon'])
        city_max_temp = (city_weather["main"]["temp_max"])
        city_humidity = (city_weather["main"]["humidity"])
        city_clouds = (city_weather['clouds']['all'])
        city_wind = (city_weather["wind"]["speed"])
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | trinidad
# Processing Record 3 of Set 1 | new norfolk
# Processing Record 4 of Set 1 | jamestown
# Processing Record 5 of Set 1 | multai
# Processing Record 6 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 1 | chokurdakh
# Processing Record 10 of Set 1 | port alfred
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | hobart
# Processing Record 13 of Set 1 | klaksvik
# Processing Record 14 of Set 1 | bandarbeyla
# Processing Record 15 of Set 1 | pechory
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | saint-philippe
# Processing Record 18 of Set 1 | bharatpur
# Processing Record 19 of Set 1 | dikson
# Processing Record 20 of Set 1 | isiolo
# ...

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)


# Show Record Count
city_data_df.count()
# Out:
# City          565
# Lat           565
# Lng           565
# Max Temp      565
# Humidity      565
# Cloudiness    565
# Wind Speed    565
# Country       565
# Date          565
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    busselton -33.6500  115.3333    300.99        38           2        2.96
# 1     trinidad -14.8333  -64.9000    295.72        95          91        1.96
# 2  new norfolk -42.7826  147.0587    300.86        35         100        1.79
# 3    jamestown  42.0970  -79.2353    271.32        72           0        2.06
# 4       multai  21.7667   78.2500    296.80        37          60        4.57
#
#   Country        Date
# 0      AU  1674626923
# 1      BO  1674626923
# 2      AU  1674626924
# 3      US  1674626649
# 4      IN  1674626924

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          busselton -33.6500  115.3333    300.99        38           2
# 1           trinidad -14.8333  -64.9000    295.72        95          91
# 2        new norfolk -42.7826  147.0587    300.86        35         100
# 3          jamestown  42.0970  -79.2353    271.32        72           0
# 4             multai  21.7667   78.2500    296.80        37          60
#
#          Wind Speed Country        Date
# City_ID
# 0              2.96      AU  1674626923
# 1              1.96      BO  1674626923
# 2              1.79      AU  1674626924
# 3              2.06      US  1674626649
# 4              4.57      IN  1674626924

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
#latitude_scatter = city_data_df.loc[city_data_df["Lat"]]
latitude_scatter = city_data_df["Lat"]
#temperature_scatter = city_data_df.loc[city_data_df["Max Temp"]]
temperature_scatter = city_data_df["Max Temp"]

# Incorporate the other graph properties
plt.scatter(latitude_scatter, temperature_scatter, marker="o", edgecolors="black", s=latitude_scatter)
plt.title("City Max Latitude vs. Temperature (2022-10-18)")
plt.ylabel("Max Temperature (C)")
plt.xlabel("Latitude")
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
##rough draft ##grid
# Build the scatter plots for latitude vs. humidity
latitude_scatter = city_data_df["Lat"]
humidity_scatter = city_data_df["Humidity"]

# Incorporate the other graph properties
plt.scatter(latitude_scatter, humidity_scatter, marker="o", edgecolors="black", s=latitude_scatter)
plt.title("City Latitude vs. Humidity (2022-10-18)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
latitude_scatter = city_data_df["Lat"]
cloudiness_scatter = city_data_df["Cloudiness"]

# Incorporate the other graph properties
plt.scatter(latitude_scatter, cloudiness_scatter, marker="o", edgecolors="black", s=latitude_scatter)
plt.title("City Latitude vs. Cloudiness (2022-10-18)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
latitude_scatter = city_data_df["Lat"]
wind_speed_scatter = city_data_df["Wind Speed"]

# Incorporate the other graph properties
plt.scatter(latitude_scatter, wind_speed_scatter, marker="o", edgecolors="black", s=latitude_scatter)
plt.title("City Latitude vs. Wind Speed (2022-10-18)")
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE
def linear_regression_plot(x_values, y_values):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    x_position = x_values.min()
    y_position = y_values.min()
    #plt.annotate(line_eq,(5.8,290),fontsize=15,color="red")
    plt.annotate(line_eq,(x_position,y_position),fontsize=15,color="red")
    #plt.xlabel('Latitude')
    #plt.ylabel('Median House Prices ($100,000)')
    print(f"The r-squared is: {rvalue**2}")
    #plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0, :]

# Display sample data
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 3          jamestown  42.0970  -79.2353    271.32        72           0
# 4             multai  21.7667   78.2500    296.80        37          60
# 6         chokurdakh  70.6333  147.9167    239.40        96         100
# 10          klaksvik  62.2266   -6.5890    279.66        83          46
# 11       bandarbeyla   9.4942   50.8122    297.99        64          50
#
#          Wind Speed Country        Date
# City_ID
# 3              2.06      US  1674626649
# 4              4.57      IN  1674626924
# 6              0.95      RU  1674626925
# 10            12.42      FO  1674626926
# 11             8.35      SO  1674626926

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0, :]

# Display sample data
southern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          busselton -33.6500  115.3333    300.99        38           2
# 1           trinidad -14.8333  -64.9000    295.72        95          91
# 2        new norfolk -42.7826  147.0587    300.86        35         100
# 5            mataura -46.1927  168.8643    291.82        55          32
# 7        port alfred -33.5906   26.8910    292.69        75         100
#
#          Wind Speed Country        Date
# City_ID
# 0              2.96      AU  1674626923
# 1              1.96      BO  1674626923
# 2              1.79      AU  1674626924
# 5              3.42      NZ  1674626924
# 7              1.79      ZA  1674626925

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']
linear_regression_plot(x_values, y_values)

#(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
#regress_values = x_values * slope + intercept
#line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
#plt.scatter(x_values,y_values)
#plt.plot(x_values,regress_values,"r-")
#plt.annotate(line_eq,(5,250),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
#print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.6913304283105567

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']
linear_regression_plot(x_values, y_values)
#plt.annotate(line_eq,(5.8,240),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')

plt.show()
# Out:
# The r-squared is: 0.12487981132938172

# %% [markdown]
# **Discussion about the linear relationship:** In the Northern hemisphere, the relationship between temperatuve vs latitude is inversely proportional. The r- squared suggest a strong relationship. Meanwhile, the southern hemisphere suggests a positive proportional trend,but the r-square isnt as strong.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']
linear_regression_plot(x_values, y_values)
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.show()
# Out:
# The r-squared is: 0.22476496530443338

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']
linear_regression_plot(x_values, y_values)
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.show()
# Out:
# The r-squared is: 0.2295352342171138

# %% [markdown]
# **Discussion about the linear relationship:** In the Northern hemisphere, the relationship between temperatuve vs humidity is  proportional because its slope is positive. The r- squared suggest a not so strong relationship as it is  0.22476496530443338. Meanwhile, the southern hemisphere suggests a positive relationsip as well because it has a positive slope. But the r-square isnt as strong also at 0.2295352342171138.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']
linear_regression_plot(x_values, y_values)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.show()
# Out:
# The r-squared is: 0.0954953339789976

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']
linear_regression_plot(x_values, y_values)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.show()
# Out:
# The r-squared is: 0.23832317075204462

# %% [markdown]
# **Discussion about the linear relationship:** Both Northern and Southern hemisphere, have a positive slope indicating a positive relationship with latititude and cloudiness. Nonetheless, the southern hemisphere data is steeper and has an r-square of  0.23832317075204462. Meanwhile, the northern one has an r-square of 0.0954953339789976.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']
linear_regression_plot(x_values, y_values)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.show()
# Out:
# The r-squared is: 0.01628215239884761

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']
linear_regression_plot(x_values, y_values)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.show()
# Out:
# The r-squared is: 0.09234713366660176

# %% [markdown]
# **Discussion about the linear relationship:** We analyzed the relationship of Cloudiness with the latitude. On the northern Hemisphere we see a somewhat of a flat looking slope but it is increasing. The r-square is not strong as it is 0.01628215239884761. Meanwhile, the southern hemisphere is a negative slope with a not so strong r-square aswell 0.09234713366660176.
